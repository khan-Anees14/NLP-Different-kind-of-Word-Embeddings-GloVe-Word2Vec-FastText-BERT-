# %% [markdown]
# ### **Train a deep neural network model in PyTorch for multi-label text classification**

# %%
import pandas as pd
tweet = pd.read_csv('mLabel_tweets.csv', usecols=[1,2], names=['tweet', 'labels'],skiprows=1 )

# %%
# tweet['labels'] = "_label_" + tweet['labels'].astype(str)

# %%
# tweet['tweet_label'] = tweet['labels'] + ' ' + tweet['tweet']

# %% [markdown]
# ### **Preprocess text before loding to model**

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer

nltk.download('stopwords')
nltk.download('wordnet')

stopwords = set(stopwords.words('english'))
lematizer = WordNetLemmatizer()

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r"http\S+|www\S+|https\S+", "", text)
    text = re.sub(r"[^a-zA-Z\s]", "", text)
    words = text.split()

    clean_words = [ lematizer.lemmatize(w) for w in words if w not in stopwords ]

    return " ".join(clean_words)

tweet['tweet'] = tweet['tweet'].astype(str).apply(preprocess_text)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\NCS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\NCS\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from sklearn.model_selection import train_test_split

X = tweet['tweet']
y = tweet['labels']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.3)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((6944,), (2977,), (6944,), (2977,))

# %% [markdown]
# ### **Multi Label Binarizer**

# %%
from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer()

y_train = mlb.fit_transform(y_train)
y_test  = mlb.transform(y_test)

num_classes = len(mlb.classes_)
print("Number of classes:", num_classes)
# Out:
# Number of classes: 21

# %% [markdown]
# ### **Tokenize**

# %%
from nltk.tokenize import word_tokenize

def tokenize_text(docs):
    return [ [w.lower() for w in word_tokenize(text) if w.isalpha()] for text in docs ]

X_train_tokens = tokenize_text(X_train)
X_test_tokens  = tokenize_text(X_test)

# %% [markdown]
# ### **Glove Embeddings**

# %%
import gensim.downloader as api
fasttext_model = api.load('fasttext-wiki-news-subwords-300')
EMB_DIM = fasttext_model.vector_size

import numpy as np

# Convert documents → vector embeddings
def document_vector(tokens):
    tokens = [w for w in tokens if w in fasttext_model]
    if len(tokens) == 0:
        return np.zeros(EMB_DIM)
    return np.mean(fasttext_model[tokens], axis=0)

X_train_vec = np.array([document_vector(t) for t in X_train_tokens], dtype=np.float32)
X_test_vec  = np.array([document_vector(t) for t in X_test_tokens], dtype=np.float32)
# Out:
# [==================================================] 100.0% 958.5/958.4MB downloaded

# %% [markdown]
# ### **Creating DataLoaders to feed into MLP**

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

train_dataset = TensorDataset(torch.tensor(X_train_vec), torch.tensor(y_train, dtype=torch.float32))
test_dataset  = TensorDataset(torch.tensor(X_test_vec), torch.tensor(y_test,  dtype=torch.float32))

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader  = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# ### **Text Classifier MLP**

# %%
class TextClassifier(nn.Module):
    def __init__(self, in_feature, out_feature):
        super().__init__()
        self.fc1 = nn.Linear(in_feature, 128)
        self.dropout = nn.Dropout(0.3)
        self.fc2 = nn.Linear(128, out_feature)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        return self.fc2(x)

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)

fasttext_model = TextClassifier(EMB_DIM, num_classes).to(device)
loss_fn = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(fasttext_model.parameters(), lr=1e-4)
# Out:
# Using device: cpu

# %% [markdown]
# ### **Training Loop**

# %%
epochs = 50
for epoch in range(epochs):
    total_loss = 0
    correct = 0
    total = 0

    fasttext_model.train()
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)

        optimizer.zero_grad()
        preds = fasttext_model(xb)
        loss = loss_fn(preds, yb)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        prob = torch.sigmoid(preds)
        pred_label = (prob > 0.5).float()
        correct += (pred_label == yb).sum().item()
        total += yb.numel()

    acc = correct / total
    loss = total_loss/len(train_loader)
    print(f"Epoch {epoch+1}/{epochs} Train Loss: {loss:.2f} | Train Accuracy: {acc:.4f}")

print("FastText Model Training Completed 🎉")
# Out:
# Epoch 1/50 Train Loss: 0.67 | Train Accuracy: 0.6451
# Epoch 45/50 Train Loss: 0.47 | Train Accuracy: 0.7715
# Epoch 46/50 Train Loss: 0.47 | Train Accuracy: 0.7719
# Epoch 47/50 Train Loss: 0.47 | Train Accuracy: 0.7726
# Epoch 48/50 Train Loss: 0.47 | Train Accuracy: 0.7719
# Epoch 49/50 Train Loss: 0.47 | Train Accuracy: 0.7724
# Epoch 50/50 Train Loss: 0.47 | Train Accuracy: 0.7728
# FastText Model Training Completed 🎉

# %% [markdown]
# ### **Prediction Code**

# %%
from sklearn.metrics import f1_score

fasttext_model.eval()
all_preds, all_labels, all_probas = [], [], []

with torch.no_grad():
    for xb, yb in test_loader:
        xb = xb.to(device)
        out = torch.sigmoid(fasttext_model(xb))
        prob = out.cpu().numpy()
        preds = (prob > 0.5).astype(int)
        
        all_probas.extend(prob)
        all_preds.extend(preds)
        all_labels.extend(yb.numpy())

# %% [markdown]
# ### **Classification Report + F1-Scores**

# %%
from sklearn.metrics import classification_report

print("Classification Report:\n")
print(classification_report(all_labels, all_preds, target_names=mlb.classes_))

print("\nMicro F1 Score:", f1_score(all_labels, all_preds, average="micro"))
print("Macro F1 Score:", f1_score(all_labels, all_preds, average="macro"))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#                    0.00      0.00      0.00       601
#            -       0.75      0.65      0.70      1121
#            a       0.69      0.47      0.56      1032
#            c       0.74      0.91      0.82      2062
#            d       0.72      0.78      0.75      1778
#            e       0.85      0.95      0.90      2362
#            f       0.74      0.77      0.75      1572
#            g       0.00      0.00      0.00       160
#            h       0.71      0.17      0.27       803
#            i       0.73      0.86      0.79      1923
#            l       0.00      0.00      0.00       191
#            m       0.68      0.29      0.41       610
#            n       0.69      0.64      0.67      1377
#            o       0.56      0.28      0.37       778
#            p       0.68      0.31      0.43       648
#            r       0.67      0.59      0.63      1422
#            s       0.75      0.81      0.78      1857
#            t       0.73      0.93      0.82      2076
#            u       0.00      0.00      0.00       739
#            v       0.00      0.00      0.00       493
#            y       0.60      0.01      0.02       636
#
#    micro avg       0.74      0.64      0.68     24241
#    macro avg       0.54      0.45      0.46     24241
# weighted avg       0.66      0.64      0.63     24241
#  samples avg       0.73      0.65      0.67     24241
#
#
# Micro F1 Score: 0.6840452816839127
# Macro F1 Score: 0.45944938655893774
# a:\V_ENV\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# ### **Confusion Matrix (Label-wise Heatmap)**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

for i, label in enumerate(mlb.classes_):
    cm = confusion_matrix([lbl[i] for lbl in all_labels],
                          [pred[i] for pred in all_preds])

    plt.figure(figsize=(3, 3))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.title(f"Confusion Matrix: {label}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

# %% [markdown]
# ### **ROC–AUC (Per-Class + Combined Plot)**

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc

plt.figure(figsize=(8, 6))

for i, label in enumerate(mlb.classes_):
    fpr, tpr, _ = roc_curve([lbl[i] for lbl in all_labels],
                            [prob[i] for prob in all_probas])
    auc_score = auc(fpr, tpr)

    plt.plot(fpr, tpr, label=f"{label} AUC={auc_score:.3f}")

plt.plot([0,1], [0,1], linestyle='--')
plt.title("ROC Curve by Class")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid(True)
plt.show()

# Macro-Average ROC-AUC
macro_auc = roc_auc_score(all_labels, all_probas, average="macro")
micro_auc = roc_auc_score(all_labels, all_probas, average="micro")
print("Macro ROC-AUC:", macro_auc)
print("Micro ROC-AUC:", micro_auc)
# Out:
# Macro ROC-AUC: 0.7644199665868365
# Micro ROC-AUC: 0.8469389064583037
